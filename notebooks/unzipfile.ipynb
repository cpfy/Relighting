# %% [markdown]
# 挂载Drive

# %%
from google.colab import drive
drive.mount('/gdrive') ## mount drive
# Out:
# Mounted at /gdrive

# %% [markdown]
# 具体解压缩文件

# %%
# !unzip '/gdrive/My Drive/NeuralRecon-W-test/data/brandenburg_gate.zip' -d '/gdrive/My Drive/NeuralRecon-W-test/data/heritage-recon/'
# Out:
# Archive:  /gdrive/My Drive/NeuralRecon-W-test/data/brandenburg_gate.zip
#    creating: /gdrive/My Drive/NeuralRecon-W-test/data/heritage-recon/brandenburg_gate/brandenburg_gate/
#   inflating: /gdrive/My Drive/NeuralRecon-W-test/data/heritage-recon/brandenburg_gate/brandenburg_gate/brandenburg_gate.ply
#   inflating: /gdrive/My Drive/NeuralRecon-W-test/data/heritage-recon/brandenburg_gate/brandenburg_gate/brandenburg_gate.tsv
#   inflating: /gdrive/My Drive/NeuralRecon-W-test/data/heritage-recon/brandenburg_gate/brandenburg_gate/config.yaml
#    creating: /gdrive/My Drive/NeuralRecon-W-test/data/heritage-recon/brandenburg_gate/brandenburg_gate/dense/
#    creating: /gdrive/My Drive/NeuralRecon-W-test/data/heritage-recon/brandenburg_gate/brandenburg_gate/dense/images/
#   inflating: /gdrive/My Drive/NeuralRecon-W-test/data/heritage-recon/brandenburg_gate/brandenburg_gate/dense/images/._16127153_9315984049.jpg
# ...

# %% [markdown]
# 剩下三个也处理了

# %%
# !unzip '/gdrive/My Drive/NeuralRecon-W-test/data/lincoln_memorial.zip' -d '/gdrive/My Drive/NeuralRecon-W-test/data/heritage-recon/'
# !unzip '/gdrive/My Drive/NeuralRecon-W-test/data/palacio_de_bellas_artes.zip' -d '/gdrive/My Drive/NeuralRecon-W-test/data/heritage-recon/'
# !unzip '/gdrive/My Drive/NeuralRecon-W-test/data/pantheon_exterior.zip' -d '/gdrive/My Drive/NeuralRecon-W-test/data/heritage-recon/'
# Out:
# 流式输出内容被截断，只能显示最后 5000 行内容。
#   inflating: /gdrive/My Drive/NeuralRecon-W-test/data/heritage-recon/palacio_de_bellas_artes/dense/images/44916352241_75a7036e68_b.jpg
#   inflating: /gdrive/My Drive/NeuralRecon-W-test/data/heritage-recon/palacio_de_bellas_artes/dense/images/4492506688_1557355ab0_o.jpg
#   inflating: /gdrive/My Drive/NeuralRecon-W-test/data/heritage-recon/palacio_de_bellas_artes/dense/images/4516650442_16d8f0af87_o.jpg
#   inflating: /gdrive/My Drive/NeuralRecon-W-test/data/heritage-recon/palacio_de_bellas_artes/dense/images/45177537714_a8b7ec5045_o.jpg
#   inflating: /gdrive/My Drive/NeuralRecon-W-test/data/heritage-recon/palacio_de_bellas_artes/dense/images/4521886507_a1e9327e9d_o.jpg
#   inflating: /gdrive/My Drive/NeuralRecon-W-test/data/heritage-recon/palacio_de_bellas_artes/dense/images/4521888625_086a219012_o.jpg
#   inflating: /gdrive/My Drive/NeuralRecon-W-test/data/heritage-recon/palacio_de_bellas_artes/dense/images/45272268225_e11427c0a7_b.jpg
# ...
